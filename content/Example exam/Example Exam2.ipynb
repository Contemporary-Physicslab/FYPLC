# %% [markdown]
# # Final Exam Python, Data-analysis en Measuring & Uncertainty
#
# For this exam, you have three hours (November 3; 13:30h–16:30h). The work must be done individually. Documentation for Numpy, Scipy, and Matplotlib is provided, as well as notebooks 1–6. A PDF of the exam is also available.
#
# - Communication with others is not allowed.
# - The use of ChatGPT, Co-Pilot, or any other AI is not permitted.
#
# Important:
# - Submit your work in a way that makes the code understandable.
# - Meta-code (explanations about your code) is just as important as the code itself.
# - Always use significant figures and include corresponding units in your final answers.

# %% [markdown]
# # Assignment 1: Probabilities with Dice
# In probability theory, it is common to calculate outcomes of rolling dice. Experimental physicists, however, are often inclined to actually roll the dice and determine the probability that way. Fortunately, we can also simulate the rolling process computationally.
#
# a) Simulate the rolling of two dice. Based on 1000 rolls, what is the probability that the values of the two dice differ by 2?  Also determine the uncertainty in this probability and show whether or not this value is consistent with the true probability (8/36). Note that simulating a single die can be done with the function: `np.random.randint(1, 7, N)`

# %%
# Your code

# %% [markdown]
# b) Simulate the rolling of two dice, where you sum the total number of pips as a function of the number of rolls ($N_{\text{max}} = 100$). Plot the sum of total number of pips as a function of the number of rolls.
# It is expected that the total number of eyes $O(N)$ can be described as $O(N) = aN$, where ($a = 7$) for two dice (since this is the expected value).
# Show, using a fit function, that this relationship holds by providing the value of $a$ and its uncertainty.

# %%
# Your code

# %% [markdown]
# c) Based on a simulation of rolling two dice, determine the probability that the next roll is identical to the previous one, where the dice are indistinguishable - for example, the rolls 1-2 and 2-1 are considered identical.
# Note: The uncertainty in the probability does not need to be calculated.

# %%
### Your code

# %% [markdown]
# +++ { "page-break": true }
#
# The central limit theorem states that the sum (or mean) of a sufficiently large number of independent random variables, each with a finite mean and variance, can be described by a normal distribution, regardless of the underlying probability distribution of the variable. This normal distribution is given by $\frac{1}{\sigma \sqrt{2\pi}} e^{-\frac{(x - \mu)^2}{2\sigma^2}},$
# where $\mu$ is the mean and $\sigma$ is the standard deviation.
#
# Below, we will examine the central limit theorem for a biased die.
#
# The chosen die has following probability distribution:
# | Result | Probability |
# | --- | --- |
# | 1 | $.3$ |
# | 2 | $\frac{1}{6}$ |
# | 3 | $.25$ |
# | 4 | $\frac{2}{6} - 0.25$ |
# | 5 | $\frac{1}{6}$ |
# | 6 | $\frac{2}{6} - 0.3$ |
#
# d) Calculate the expected value of the sum obtained from rolling this die 500 times. Do this:
#
# 1. Based on the probabilities given in the table, and
# 2. Based on a simulation.
#
# N.B. You can look at the numpy documentation for random.choice(...).

# %%
# Your code

# %% [markdown]
# e) Simulate the following experiment and carry out the tasks below:
#
# 1. Perform 1000 repeated experiments, where each experiment consists of 500 rolls of the biased die, and the total number of pips is taken as the outcome of that experiment (thus a value greater than 499 but less than 3001).
#
# 2. Plot a histogram of these 1000 experimental outcomes.
#
# 3. Fit a normal distribution to your experimental results and report both the mean and the standard deviation, including their corresponding uncertainties.

# %%
# Your code

# %% [markdown]
# +++ { "page-break": true }

# %% [markdown]
# # The Resistance of a Wire
# Measurements have been performed on a copper wire.
# The diameter of the wire is $1.0 \pm 0.2$ mm.
# The length of the wire is $0.75 \pm 0.03$ m.
# The resistivity is $(17.1 \pm 0.2) \cdot 10^{-9}\ \Omega\text{m}$ .
# The resistance of the wire can be calculated using:
# ${R = \rho \cdot \frac{l}{A}},$
# where $R$ is the resistance of the wire, $\rho$ is the resistivity in $\Omega \text{m}$, $l$ is the length of the wire in meters, and $A$ is the cross-sectional area in $\text{m}^2$.
#
# Calculate the resistance of this copper wire.
# Use the functional approach to determine the measurement uncertainty.
# Print the result (including its uncertainty) with the correct number of significant figures.

# %%
### Your code
